# %%
#getting and working with data
import pandas as pd
from sklearn.cluster import KMeans,DBSCAN
from sklearn.preprocessing import StandardScaler, Normalizer
import numpy as np
from sklearn.metrics.cluster import silhouette_score

#visualizing results
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

from IPython.display import display

# %%
breast_cancer_data = pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.data",
                        names=["Sample code number","Clump Thickness","Uniformity of Cell Size","Uniformity of Cell Shape","Marginal Adhesion", "Single Epithelial Cell Size", "Bare Nuclei", "Bland Chromatin", "Normal Nucleoli", "Mitoses", "Class"])

# %%
display(breast_cancer_data.head())
# Out:
#    Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0             1000025                5                        1
# 1             1002945                5                        4
# 2             1015425                3                        1
# 3             1016277                6                        8
# 4             1017023                4                        1
#
#    Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                         1                  1                            2
# 1                         4                  5                            7
# 2                         1                  1                            2
# 3                         8                  1                            3
# 4                         1                  3                            2
#
#   Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# ...

# %%
sns.pairplot(breast_cancer_data)

# %%
breast_cancer_data.dtypes
# Out:
# Sample code number              int64
# Clump Thickness                 int64
# Uniformity of Cell Size         int64
# Uniformity of Cell Shape        int64
# Marginal Adhesion               int64
# Single Epithelial Cell Size     int64
# Bare Nuclei                    object
# Bland Chromatin                 int64
# Normal Nucleoli                 int64
# Mitoses                         int64
# Class                           int64
# dtype: object

# %%
breast_cancer_data.columns
# Out:
# Index(['Sample code number', 'Clump Thickness', 'Uniformity of Cell Size',
#        'Uniformity of Cell Shape', 'Marginal Adhesion',
#        'Single Epithelial Cell Size', 'Bare Nuclei', 'Bland Chromatin',
#        'Normal Nucleoli', 'Mitoses', 'Class'],
#       dtype='object')

# %%
print(breast_cancer_data.shape)
# Out:
# (699, 11)

# %%
breast_cancer_data.columns = breast_cancer_data.columns.map(lambda x: x.replace(" ","_"))

# %%
breast_cancer_data.columns
# Out:
# Index(['Sample_code_number', 'Clump_Thickness', 'Uniformity_of_Cell_Size',
#        'Uniformity_of_Cell_Shape', 'Marginal_Adhesion',
#        'Single_Epithelial_Cell_Size', 'Bare_Nuclei', 'Bland_Chromatin',
#        'Normal_Nucleoli', 'Mitoses', 'Class'],
#       dtype='object')

# %%
breast_cancer_data["Bare_Nuclei"] = breast_cancer_data["Bare_Nuclei"].astype(str)

# %%
breast_cancer_data["Bare_Nuclei"] = breast_cancer_data["Bare_Nuclei"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-e2acdb3bd3b9> in <module>()
# ----> 1 breast_cancer_data["Bare_Nuclei"] = breast_cancer_data["Bare_Nuclei"].astype(int)
#
# C:\Users\Padraigbuckley7\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, raise_on_error, **kwargs)
#    3052         # else, only a single dtype is given
#    3053         new_data = self._data.astype(dtype=dtype, copy=copy,
# -> 3054                                      raise_on_error=raise_on_error, **kwargs)
#    3055         return self._constructor(new_data).__finalize__(self)
#    3056
#
# C:\Users\Padraigbuckley7\Anaconda3\lib\site-packages\pandas\core\internals.py in astype(self, dtype, **kwargs)
#    3187
#    3188     def astype(self, dtype, **kwargs):
# -> 3189         return self.apply('astype', dtype=dtype, **kwargs)
#    3190
# ...

# %%
breast_cancer_data.Bare_Nuclei.value_counts()
# Out:
# 1     402
# 10    132
# 2      30
# 5      30
# 3      28
# 8      21
# 4      19
# ?      16
# 9       9
# 7       8
# 6       4
# Name: Bare_Nuclei, dtype: int64

# %%
breast_cancer_data = breast_cancer_data[~breast_cancer_data.Bare_Nuclei.str.contains("?")]
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-29-1e91efedc817> in <module>()
# ----> 1 breast_cancer_data = breast_cancer_data[~breast_cancer_data.Bare_Nuclei.str.contains("?")]
#
# C:\Users\Padraigbuckley7\Anaconda3\lib\site-packages\pandas\core\strings.py in contains(self, pat, case, flags, na, regex)
#    1492     def contains(self, pat, case=True, flags=0, na=np.nan, regex=True):
#    1493         result = str_contains(self._data, pat, case=case, flags=flags, na=na,
# -> 1494                               regex=regex)
#    1495         return self._wrap_result(result)
#    1496
#
# C:\Users\Padraigbuckley7\Anaconda3\lib\site-packages\pandas\core\strings.py in str_contains(arr, pat, case, flags, na, regex)
#     235             flags |= re.IGNORECASE
#     236
# --> 237         regex = re.compile(pat, flags=flags)
#     238
# ...

# %%
breast_cancer_data = breast_cancer_data[breast_cancer_data.Bare_Nuclei.str.contains("?") == FALSE]
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-30-f4c516c62fcd> in <module>()
# ----> 1 breast_cancer_data = breast_cancer_data[breast_cancer_data.Bare_Nuclei.str.contains("?") == FALSE]
#
# C:\Users\Padraigbuckley7\Anaconda3\lib\site-packages\pandas\core\strings.py in contains(self, pat, case, flags, na, regex)
#    1492     def contains(self, pat, case=True, flags=0, na=np.nan, regex=True):
#    1493         result = str_contains(self._data, pat, case=case, flags=flags, na=na,
# -> 1494                               regex=regex)
#    1495         return self._wrap_result(result)
#    1496
#
# C:\Users\Padraigbuckley7\Anaconda3\lib\site-packages\pandas\core\strings.py in str_contains(arr, pat, case, flags, na, regex)
#     235             flags |= re.IGNORECASE
#     236
# --> 237         regex = re.compile(pat, flags=flags)
#     238
# ...

# %%
breast_cancer_data.dtypes
# Out:
# Sample_code_number              int64
# Clump_Thickness                 int64
# Uniformity_of_Cell_Size         int64
# Uniformity_of_Cell_Shape        int64
# Marginal_Adhesion               int64
# Single_Epithelial_Cell_Size     int64
# Bare_Nuclei                    object
# Bland_Chromatin                 int64
# Normal_Nucleoli                 int64
# Mitoses                         int64
# Class                           int64
# dtype: object

# %%
breast_cancer_data["Bare_Nuclei"] = breast_cancer_data["Bare_Nuclei"].astype('str')
print("hello")
# Out:
# hello

# %%
breast_cancer_data.dtypes
# Out:
# Sample_code_number              int64
# Clump_Thickness                 int64
# Uniformity_of_Cell_Size         int64
# Uniformity_of_Cell_Shape        int64
# Marginal_Adhesion               int64
# Single_Epithelial_Cell_Size     int64
# Bare_Nuclei                    object
# Bland_Chromatin                 int64
# Normal_Nucleoli                 int64
# Mitoses                         int64
# Class                           int64
# dtype: object

# %%
breast_cancer_data.dtypes
# Out:
# Sample_code_number              int64
# Clump_Thickness                 int64
# Uniformity_of_Cell_Size         int64
# Uniformity_of_Cell_Shape        int64
# Marginal_Adhesion               int64
# Single_Epithelial_Cell_Size     int64
# Bare_Nuclei                    object
# Bland_Chromatin                 int64
# Normal_Nucleoli                 int64
# Mitoses                         int64
# Class                           int64
# dtype: object

# %%
breast_cancer_data.Bare_Nuclei.value_counts()
# Out:
# 1     402
# 10    132
# 2      30
# 5      30
# 3      28
# 8      21
# 4      19
# ?      16
# 9       9
# 7       8
# 6       4
# Name: Bare_Nuclei, dtype: int64

# %%
type(breast_cancer_data)
# Out:
# pandas.core.frame.DataFrame

# %%
breast_cancer_data = breast_cancer_data[breast_cancer_data.Bare_Nuclei != "?"]

# %%
breast_cancer_data.Bare_Nuclei.value_counts()
# Out:
# 1     402
# 10    132
# 2      30
# 5      30
# 3      28
# 8      21
# 4      19
# 9       9
# 7       8
# 6       4
# Name: Bare_Nuclei, dtype: int64

# %%
breast_cancer_data.dtypes
# Out:
# Sample_code_number              int64
# Clump_Thickness                 int64
# Uniformity_of_Cell_Size         int64
# Uniformity_of_Cell_Shape        int64
# Marginal_Adhesion               int64
# Single_Epithelial_Cell_Size     int64
# Bare_Nuclei                    object
# Bland_Chromatin                 int64
# Normal_Nucleoli                 int64
# Mitoses                         int64
# Class                           int64
# dtype: object

# %%
breast_cancer_data.Bare_Nuclei.dtype
# Out:
# dtype('O')

# %%
breast_cancer_data["Bare_Nuclei"] = breast_cancer_data["Bare_Nuclei"].astype('str').astype('int')
# Out:
# C:\Users\Padraigbuckley7\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
breast_cancer_data.dtypes
# Out:
# Sample_code_number             int64
# Clump_Thickness                int64
# Uniformity_of_Cell_Size        int64
# Uniformity_of_Cell_Shape       int64
# Marginal_Adhesion              int64
# Single_Epithelial_Cell_Size    int64
# Bare_Nuclei                    int32
# Bland_Chromatin                int64
# Normal_Nucleoli                int64
# Mitoses                        int64
# Class                          int64
# dtype: object
